# %% [markdown]
# ## CLIPSPY clinical decision support rules

# %% [markdown]
# ### Developing CDS rules to data extracted using a FHIR server
#
# #### Note: To be done AFTER the hands-on tutorial and the tutorial on rule programming

# %% [markdown]
# #### Requirements
#
# 1. install into the same Python environment as clipspy the Python FHIR client: https://github.com/dbmi-pitt/client-py.git
#
# 1.1. download the file https://github.com/dbmi-pitt/client-py/blob/master/fhirclient-4.0.0.tar.gz
#
# 1.2. change to the folder where you saved the file and use pip from the command line: pip install fhirclient-4.0.0.tar.gz
#
#
# 2. xmljson: https://pypi.org/project/xmljson/ (should install easily with pip: pip install xmljson
#
# 3. the Pitt VPN running with the DBMI role
#
# 4. confirm that the FHIR server is accessible and running by going to this URL in your browser:
#
# http://130.49.206.139:8080/omoponfhir-stu3/tester/

# %% [markdown]
# #### E6: Exercise writing and applying production rules
#
# Your task is to implement the drug interaction CDS algorithm described at https://ddi-cds.org/warfarin-antidepressants/. You will test your rule-based implementation of the algorithm by running it over facts that you create from the Patient, MedicationPlan, and Condition FHIR resources queried above. The value sets for all of the drugs and conditions used in the algorithm are loaded into working memory using the blocks above. Your job is to:
#
# 1. Develop templates for the three key knowledge entities (patients, medications, and conditions). You do not need to represent all FHIR resource properties, only those that matter for the algorithm
#
# 2. Develop rules that implement the logic diagram shown on the web page so that each branch of the rule is covered. Aim for your rules to be as modular as possible. It is better for you to create allot of very simple rules than try to create a small number of relatively complex rules. Let the reasoner do most of the work.
#
# 3. Load the entire dataset retrieved in the blocks above into CLIPS working memory as facts that use your templates. Use Python to translate from the FHIR resources to strings representing facts, and then load those facts into the CLIPS environment.
#
# 4. Run the rule engine so that it produces an operational classification with respect to the drug interaction algorithm (leaf nodes in the diagram) for each patient. Show the patients that are exposed to the interacting drugs and what oparational classification the algorithm would assign them.
#
#
# NOTE: All visits, drugs, conditions start on 2/13/2008 and end on 4/27/2008. Also, there are 7 patients that should trigger a rule branch
#
# NOTE: I suggest that you append log information to the global variable ?\*log\* because STDERR and STDOUT do not work like expected in the CLIPS environment.

# %% [markdown]
# #### Load all of the required value sets as facts

# %%
# libraries needed to load values sets as XML and convert to JSON
import xmljson
from json import dumps
from xmljson import yahoo
from xml.etree.ElementTree import fromstring

# %%
def getConceptCodes(vs):
    return vs['{urn:ihe:iti:svs:2008}RetrieveValueSetResponse']['{urn:ihe:iti:svs:2008}ValueSet']['{urn:ihe:iti:svs:2008}ConceptList']['{urn:ihe:iti:svs:2008}Concept']

# %%
## Set up the CLIPS environment
import clips
env = clips.Environment()

# %%
# Clear working memory
env.clear()
env.reset()

# Simple template for a value set
s = """
 (deftemplate valueset
    (slot vs_name)
    (slot code)
    (slot label))
"""
env.build(s)

# %%
# aldosterone-antagonists
f = open('tutorial-data/value-sets/aldosterone-antagonist-vs.xml')
buf = f.read()
f.close()
aldosterone_antagonist = yahoo.data(fromstring(buf))
ccs = getConceptCodes(aldosterone_antagonist)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('altosterone-antagonists',cc['code'],cc['displayName']))
    
# bupropions    
f = open('tutorial-data/value-sets/bupropion-vs.xml')
buf = f.read()
f.close()
bupropion = yahoo.data(fromstring(buf))
ccs = getConceptCodes(bupropion)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('bupropion',cc['code'],cc['displayName']))
   
# mirtazapine
f = open('tutorial-data/value-sets/mirtazapine-vs.xml')
buf = f.read()
f.close()
mirtazapine = yahoo.data(fromstring(buf))
ccs = getConceptCodes(mirtazapine)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('mirtazapine',cc['code'],cc['displayName']))

# nsaids
f = open('tutorial-data/value-sets/NSAIDs-vs.xml')
buf = f.read()
f.close()
nsaids = yahoo.data(fromstring(buf))
ccs = getConceptCodes(nsaids)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('nsaids',cc['code'],cc['displayName']))


# SSRIs and SNRIs
f = open('tutorial-data/value-sets/SSRI-SNRI-vs.xml')
buf = f.read()
f.close()
SSRI_SNRI = yahoo.data(fromstring(buf))
ccs = getConceptCodes(SSRI_SNRI)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('SSRI_SNRI',cc['code'],cc['displayName']))

# systemic_corticosteriods
f = open('tutorial-data/value-sets/systemic-corticosteriods-vs.xml')
buf = f.read()
f.close()
systemic_corticosteriods = yahoo.data(fromstring(buf))
ccs = getConceptCodes(systemic_corticosteriods)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('systemic_corticosteriods',cc['code'],cc['displayName']))

# tricyclic_antidepr
f = open('tutorial-data/value-sets/tricyclic-antidepressants.xml')
buf = f.read()
f.close()
tricyclic_antidepressants = yahoo.data(fromstring(buf))
ccs = getConceptCodes(tricyclic_antidepressants)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('tricyclic_antidepressants',cc['code'],cc['displayName']))

# warfarin
f = open('tutorial-data/value-sets/warfarin-vs.xml')
buf = f.read()
f.close()
warfarin = yahoo.data(fromstring(buf))
ccs = getConceptCodes(warfarin)
for cc in ccs:
    env.assert_string('''
(valueset
   (vs_name "{}")
   (code {})
   (label "{}")
)        
    '''.format('warfarin',cc['code'],cc['displayName']))

for fact in env.facts():
    print(fact)
# Out:
# (initial-fact)
# (valueset (vs_name "altosterone-antagonists") (code 104230) (label "Spironolactone 1 MG/ML Oral Suspension"))
# (valueset (vs_name "altosterone-antagonists") (code 104231) (label "Spironolactone 2 MG/ML Oral Suspension"))
# (valueset (vs_name "altosterone-antagonists") (code 104232) (label "Spironolactone 5 MG/ML Oral Suspension"))
# (valueset (vs_name "altosterone-antagonists") (code 104233) (label "Spironolactone 10 MG/ML Oral Suspension"))
# (valueset (vs_name "altosterone-antagonists") (code 198222) (label "Spironolactone 100 MG Oral Tablet"))
# (valueset (vs_name "altosterone-antagonists") (code 198223) (label "Spironolactone 50 MG Oral Tablet"))
# (valueset (vs_name "altosterone-antagonists") (code 198224) (label "Hydrochlorothiazide 25 MG / Spironolactone 25 MG Oral Tablet"))
# (valueset (vs_name "altosterone-antagonists") (code 198225) (label "Hydrochlorothiazide 50 MG / Spironolactone 50 MG Oral Tablet"))
# (valueset (vs_name "altosterone-antagonists") (code 246399) (label "Furosemide 20 MG / Spironolactone 50 MG Oral Capsule"))
# f-10    (valueset (vs_name "altosterone-antagonists") (code 250376) (label "Hydroflumethiazide 25 MG / Spironolactone 25 MG Oral Tablet"))
# f-11    (valueset (vs_name "altosterone-antagonists") (code 250377) (label "Hydroflumethiazide 50 MG / Spironolactone 50 MG Oral Tablet"))
# f-12    (valueset (vs_name "altosterone-antagonists") (code 313096) (label "Spironolactone 25 MG Oral Tablet"))
# f-13    (valueset (vs_name "altosterone-antagonists") (code 351256) (label "eplerenone 25 MG Oral Tablet"))
# f-14    (valueset (vs_name "altosterone-antagonists") (code 351257) (label "eplerenone 50 MG Oral Tablet"))
# f-15    (valueset (vs_name "altosterone-antagonists") (code 351258) (label "eplerenone 100 MG Oral Tablet"))
# f-16    (valueset (vs_name "bupropion") (code 1232585) (label "24 HR Bupropion Hydrochloride 450 MG Extended Release Oral Tablet"))
# f-17    (valueset (vs_name "bupropion") (code 1551468) (label "12 HR Bupropion Hydrochloride 90 MG / Naltrexone hydrochloride 8 MG Extended Release Oral Tablet"))
# f-18    (valueset (vs_name "bupropion") (code 993503) (label "12 HR Bupropion Hydrochloride 100 MG Extended Release Oral Tablet"))
# f-19    (valueset (vs_name "bupropion") (code 993518) (label "12 HR Bupropion Hydrochloride 150 MG Extended Release Oral Tablet"))
# f-20    (valueset (vs_name "bupropion") (code 993536) (label "12 HR Bupropion Hydrochloride 200 MG Extended Release Oral Tablet"))
# f-21    (valueset (vs_name "bupropion") (code 993541) (label "24 HR Bupropion Hydrochloride 150 MG Extended Release Oral Tablet"))
# f-22    (valueset (vs_name "bupropion") (code 993550) (label "24 HR Bupropion hydrobromide 174 MG Extended Release Oral Tablet"))
# f-23    (valueset (vs_name "bupropion") (code 993557) (label "24 HR Bupropion Hydrochloride 300 MG Extended Release Oral Tablet"))
# f-24    (valueset (vs_name "bupropion") (code 993567) (label "24 HR Bupropion hydrobromide 348 MG Extended Release Oral Tablet"))
# f-25    (valueset (vs_name "bupropion") (code 993681) (label "24 HR Bupropion hydrobromide 522 MG Extended Release Oral Tablet"))
# f-26    (valueset (vs_name "bupropion") (code 993687) (label "Bupropion Hydrochloride 100 MG Oral Tablet"))
# f-27    (valueset (vs_name "bupropion") (code 993691) (label "Bupropion Hydrochloride 75 MG Oral Tablet"))
# f-28    (valueset (vs_name "mirtazapine") (code 283406) (label "Mirtazapine 15 MG Disintegrating Oral Tablet"))
# f-29    (valueset (vs_name "mirtazapine") (code 283407) (label "Mirtazapine 30 MG Disintegrating Oral Tablet"))
# f-30    (valueset (vs_name "mirtazapine") (code 283485) (label "Mirtazapine 45 MG Disintegrating Oral Tablet"))
# f-31    (valueset (vs_name "mirtazapine") (code 311725) (label "Mirtazapine 15 MG Oral Tablet"))
# f-32    (valueset (vs_name "mirtazapine") (code 311726) (label "Mirtazapine 45 MG Oral Tablet"))
# f-33    (valueset (vs_name "mirtazapine") (code 314111) (label "Mirtazapine 30 MG Oral Tablet"))
# f-34    (valueset (vs_name "mirtazapine") (code 476809) (label "Mirtazapine 7.5 MG Oral Tablet"))
# f-35    (valueset (vs_name "nsaids") (code 1049589) (label "Ibuprofen 400 MG / Oxycodone Hydrochloride 5 MG Oral Tablet"))
# f-36    (valueset (vs_name "nsaids") (code 105833) (label "fenbufen 300 MG Oral Capsule"))
# f-37    (valueset (vs_name "nsaids") (code 105834) (label "fenbufen 300 MG Oral Tablet"))
# f-38    (valueset (vs_name "nsaids") (code 105845) (label "Flurbiprofen 100 MG Rectal Suppository"))
# f-39    (valueset (vs_name "nsaids") (code 105918) (label "Naproxen 250 MG Delayed Release Oral Tablet"))
# f-40    (valueset (vs_name "nsaids") (code 105925) (label "Phenylbutazone 200 MG Oral Tablet"))
# f-41    (valueset (vs_name "nsaids") (code 105942) (label "Piroxicam 20 MG Rectal Suppository"))
# f-42    (valueset (vs_name "nsaids") (code 105949) (label "acemetacin 60 MG Oral Capsule"))
# f-43    (valueset (vs_name "nsaids") (code 105953) (label "nabumetone 100 MG/ML Oral Suspension"))
# f-44    (valueset (vs_name "nsaids") (code 105954) (label "tenoxicam 20 MG Oral Tablet"))
# f-45    (valueset (vs_name "nsaids") (code 107313) (label "Phenylbutazone 100 MG Delayed Release Oral Tablet"))
# f-46    (valueset (vs_name "nsaids") (code 1100066) (label "Famotidine 26.6 MG / Ibuprofen 800 MG Oral Tablet"))
# f-47    (valueset (vs_name "nsaids") (code 1112231) (label "Naproxen sodium 220 MG Oral Capsule"))
# f-48    (valueset (vs_name "nsaids") (code 1116320) (label "24 HR Naproxen 375 MG Extended Release Oral Tablet"))
# f-49    (valueset (vs_name "nsaids") (code 1116339) (label "24 HR Naproxen 500 MG Extended Release Oral Tablet"))
# f-50    (valueset (vs_name "nsaids") (code 1116349) (label "24 HR Naproxen 750 MG Extended Release Oral Tablet"))
# f-51    (valueset (vs_name "nsaids") (code 1234493) (label "Diclofenac Sodium 100 MG Oral Capsule"))
# f-52    (valueset (vs_name "nsaids") (code 1236089) (label "Benzydamine Hydrochloride 3 MG Oral Lozenge"))
# f-53    (valueset (vs_name "nsaids") (code 1292323) (label "Diphenhydramine Citrate 38 MG / Ibuprofen 200 MG Oral Capsule"))
# f-54    (valueset (vs_name "nsaids") (code 1292465) (label "Phenylbutazone 0.1 MG/MG Oral Powder"))
# f-55    (valueset (vs_name "nsaids") (code 1297369) (label "Chlorpheniramine Maleate 0.2 MG/ML / Ibuprofen 20 MG/ML / Pseudoephedrine Hydrochloride 3 MG/ML Oral Suspension"))
# f-56    (valueset (vs_name "nsaids") (code 1297390) (label "Chlorpheniramine Maleate 2 MG / Ibuprofen 200 MG / Pseudoephedrine Hydrochloride 30 MG Oral Tablet"))
# f-57    (valueset (vs_name "nsaids") (code 1299018) (label "Ibuprofen 200 MG / Pseudoephedrine Hydrochloride 30 MG Oral Capsule"))
# f-58    (valueset (vs_name "nsaids") (code 1299021) (label "Ibuprofen 200 MG / Pseudoephedrine Hydrochloride 30 MG Oral Tablet"))
# f-59    (valueset (vs_name "nsaids") (code 1310487) (label "Ibuprofen 20 MG/ML / Pseudoephedrine Hydrochloride 3 MG/ML Oral Suspension"))
# f-60    (valueset (vs_name "nsaids") (code 1310503) (label "Chlorpheniramine Maleate 4 MG / Ibuprofen 200 MG / Phenylephrine Hydrochloride 10 MG Oral Tablet"))
# f-61    (valueset (vs_name "nsaids") (code 1359105) (label "Diclofenac Sodium 75 MG / Misoprostol 0.2 MG Delayed Release Oral Tablet"))
# f-62    (valueset (vs_name "nsaids") (code 1367426) (label "12 HR Naproxen sodium 220 MG / Pseudoephedrine Hydrochloride 120 MG Extended Release Oral Tablet"))
# f-63    (valueset (vs_name "nsaids") (code 1369775) (label "Ibuprofen 200 MG / Phenylephrine Hydrochloride 10 MG Oral Tablet"))
# f-64    (valueset (vs_name "nsaids") (code 141993) (label "Ibuprofen 3 MG/ML Oral Suspension"))
# f-65    (valueset (vs_name "nsaids") (code 1442116) (label "Diclofenac 18 MG Oral Capsule"))
# f-66    (valueset (vs_name "nsaids") (code 1442128) (label "Diclofenac 35 MG Oral Capsule"))
# f-67    (valueset (vs_name "nsaids") (code 1490727) (label "Indomethacin 20 MG Oral Capsule"))
# f-68    (valueset (vs_name "nsaids") (code 1491529) (label "Indomethacin 40 MG Oral Capsule"))
# f-69    (valueset (vs_name "nsaids") (code 152544) (label "aceclofenac 100 MG Oral Tablet"))
# f-70    (valueset (vs_name "nsaids") (code 152695) (label "meloxicam 15 MG Oral Tablet"))
# f-71    (valueset (vs_name "nsaids") (code 153522) (label "tolfenamic acid 200 MG Oral Tablet"))
# f-72    (valueset (vs_name "nsaids") (code 1550957) (label "Diphenhydramine Hydrochloride 25 MG / Naproxen sodium 220 MG Oral Tablet"))
# f-73    (valueset (vs_name "nsaids") (code 1551477) (label "Ketoprofen 100 MG/ML Injectable Solution"))
# f-74    (valueset (vs_name "nsaids") (code 1599787) (label "1 ML Diclofenac Sodium 37.5 MG/ML Injection"))
# f-75    (valueset (vs_name "nsaids") (code 1608797) (label "Naproxen 200 MG Oral Tablet"))
# f-76    (valueset (vs_name "nsaids") (code 1653765) (label "Naproxen sodium 60 MG / Sumatriptan 10 MG Oral Tablet"))
# f-77    (valueset (vs_name "nsaids") (code 1665459) (label "2 ML Ketorolac Tromethamine 30 MG/ML Injection"))
# f-78    (valueset (vs_name "nsaids") (code 1665461) (label "1 ML Ketorolac Tromethamine 30 MG/ML Injection"))
# f-79    (valueset (vs_name "nsaids") (code 1665675) (label "1 ML Ketorolac Tromethamine 15 MG/ML Cartridge"))
# f-80    (valueset (vs_name "nsaids") (code 1665679) (label "1 ML Ketorolac Tromethamine 30 MG/ML Cartridge"))
# f-81    (valueset (vs_name "nsaids") (code 1665682) (label "2 ML Ketorolac Tromethamine 30 MG/ML Cartridge"))
# f-82    (valueset (vs_name "nsaids") (code 197684) (label "Etodolac 200 MG Oral Capsule"))
# f-83    (valueset (vs_name "nsaids") (code 197685) (label "Etodolac 300 MG Oral Capsule"))
# f-84    (valueset (vs_name "nsaids") (code 197686) (label "Etodolac 400 MG Oral Tablet"))
# f-85    (valueset (vs_name "nsaids") (code 197694) (label "Fenoprofen 200 MG Oral Capsule"))
# f-86    (valueset (vs_name "nsaids") (code 197695) (label "Fenoprofen 300 MG Oral Capsule"))
# f-87    (valueset (vs_name "nsaids") (code 197724) (label "Flurbiprofen 100 MG Oral Tablet"))
# f-88    (valueset (vs_name "nsaids") (code 197725) (label "Flurbiprofen 50 MG Oral Tablet"))
# f-89    (valueset (vs_name "nsaids") (code 197803) (label "Ibuprofen 20 MG/ML Oral Suspension"))
# f-90    (valueset (vs_name "nsaids") (code 197805) (label "Ibuprofen 400 MG Oral Tablet"))
# f-91    (valueset (vs_name "nsaids") (code 197806) (label "Ibuprofen 600 MG Oral Tablet"))
# f-92    (valueset (vs_name "nsaids") (code 197807) (label "Ibuprofen 800 MG Oral Tablet"))
# f-93    (valueset (vs_name "nsaids") (code 197817) (label "Indomethacin 25 MG Oral Capsule"))
# f-94    (valueset (vs_name "nsaids") (code 197818) (label "Indomethacin 50 MG Oral Capsule"))
# f-95    (valueset (vs_name "nsaids") (code 197819) (label "Indomethacin 50 MG Rectal Suppository"))
# f-96    (valueset (vs_name "nsaids") (code 197854) (label "Ketoprofen 25 MG Oral Capsule"))
# f-97    (valueset (vs_name "nsaids") (code 197855) (label "Ketoprofen 50 MG Oral Capsule"))
# f-98    (valueset (vs_name "nsaids") (code 197856) (label "Ketoprofen 75 MG Oral Capsule"))
# f-99    (valueset (vs_name "nsaids") (code 198012) (label "Naproxen 375 MG Oral Tablet"))
# f-100   (valueset (vs_name "nsaids") (code 198013) (label "Naproxen 250 MG Oral Tablet"))
# f-101   (valueset (vs_name "nsaids") (code 198014) (label "Naproxen 500 MG Oral Tablet"))
# f-102   (valueset (vs_name "nsaids") (code 198107) (label "Piroxicam 10 MG Oral Capsule"))
# f-103   (valueset (vs_name "nsaids") (code 198108) (label "Piroxicam 20 MG Oral Capsule"))
# f-104   (valueset (vs_name "nsaids") (code 198238) (label "Sulindac 150 MG Oral Tablet"))
# f-105   (valueset (vs_name "nsaids") (code 198239) (label "Sulindac 200 MG Oral Tablet"))
# f-106   (valueset (vs_name "nsaids") (code 198295) (label "Tolmetin 200 MG Oral Tablet"))
# f-107   (valueset (vs_name "nsaids") (code 198296) (label "Tolmetin 400 MG Oral Capsule"))
# f-108   (valueset (vs_name "nsaids") (code 198297) (label "Tolmetin 600 MG Oral Tablet"))
# f-109   (valueset (vs_name "nsaids") (code 198405) (label "Ibuprofen 100 MG Oral Tablet"))
# f-110   (valueset (vs_name "nsaids") (code 199169) (label "Ketoprofen 12.5 MG Oral Tablet"))
# f-111   (valueset (vs_name "nsaids") (code 199279) (label "Sulindac 100 MG Oral Tablet"))
# f-112   (valueset (vs_name "nsaids") (code 199321) (label "Ketoprofen 100 MG Oral Capsule"))
# f-113   (valueset (vs_name "nsaids") (code 199390) (label "Etodolac 500 MG Oral Tablet"))
# f-114   (valueset (vs_name "nsaids") (code 199490) (label "Naproxen 500 MG Rectal Suppository"))
# f-115   (valueset (vs_name "nsaids") (code 199516) (label "tenoxicam 10 MG Oral Tablet"))
# f-116   (valueset (vs_name "nsaids") (code 199549) (label "Indomethacin 100 MG Rectal Suppository"))
# f-117   (valueset (vs_name "nsaids") (code 199553) (label "Ketoprofen 100 MG Rectal Suppository"))
# f-118   (valueset (vs_name "nsaids") (code 199559) (label "Piroxicam 10 MG Oral Tablet"))
# f-119   (valueset (vs_name "nsaids") (code 199560) (label "Piroxicam 20 MG Oral Tablet"))
# f-120   (valueset (vs_name "nsaids") (code 199740) (label "fenbufen 450 MG Oral Tablet"))
# f-121   (valueset (vs_name "nsaids") (code 199749) (label "Flurbiprofen 200 MG Extended Release Oral Capsule"))
# f-122   (valueset (vs_name "nsaids") (code 199758) (label "Ketoprofen 100 MG Delayed Release Oral Tablet"))
# f-123   (valueset (vs_name "nsaids") (code 204442) (label "Ibuprofen 40 MG/ML Oral Suspension"))
# f-124   (valueset (vs_name "nsaids") (code 205322) (label "celecoxib 100 MG Oral Capsule"))
# f-125   (valueset (vs_name "nsaids") (code 205323) (label "celecoxib 200 MG Oral Capsule"))
# f-126   (valueset (vs_name "nsaids") (code 227159) (label "Ibuprofen 200 MG Extended Release Oral Capsule"))
# f-127   (valueset (vs_name "nsaids") (code 243762) (label "Phenylbutazone 1000 MG Oral Tablet"))
# f-128   (valueset (vs_name "nsaids") (code 245419) (label "Ketoprofen 50 MG Delayed Release Oral Tablet"))
# f-129   (valueset (vs_name "nsaids") (code 245420) (label "Naproxen 125 MG Oral Tablet"))
# f-130   (valueset (vs_name "nsaids") (code 246236) (label "Ketoprofen 50 MG/ML Injectable Solution"))
# f-131   (valueset (vs_name "nsaids") (code 247066) (label "Piroxicam 10 MG Rectal Suppository"))
# f-132   (valueset (vs_name "nsaids") (code 247630) (label "Ketoprofen 50 MG Rectal Suppository"))
# f-133   (valueset (vs_name "nsaids") (code 249482) (label "Ketoprofen 100 MG Oral Tablet"))
# f-134   (valueset (vs_name "nsaids") (code 250197) (label "tenoxicam 20 MG Rectal Suppository"))
# f-135   (valueset (vs_name "nsaids") (code 250418) (label "Ibuprofen 800 MG Extended Release Oral Tablet"))
# f-136   (valueset (vs_name "nsaids") (code 250469) (label "Fenoprofen 300 MG Oral Tablet"))
# f-137   (valueset (vs_name "nsaids") (code 251255) (label "Indomethacin 25 MG Extended Release Oral Capsule"))
# f-138   (valueset (vs_name "nsaids") (code 310245) (label "24 HR Etodolac 400 MG Extended Release Oral Tablet"))
# f-139   (valueset (vs_name "nsaids") (code 310247) (label "24 HR Etodolac 600 MG Extended Release Oral Tablet"))
# f-140   (valueset (vs_name "nsaids") (code 310291) (label "Fenoprofen 600 MG Oral Tablet"))
# f-141   (valueset (vs_name "nsaids") (code 310963) (label "Ibuprofen 100 MG Chewable Tablet"))
# f-142   (valueset (vs_name "nsaids") (code 310964) (label "Ibuprofen 200 MG Oral Capsule"))
# f-143   (valueset (vs_name "nsaids") (code 310965) (label "Ibuprofen 200 MG Oral Tablet"))
# f-144   (valueset (vs_name "nsaids") (code 310991) (label "Indomethacin 5 MG/ML Oral Suspension"))
# f-145   (valueset (vs_name "nsaids") (code 310992) (label "Indomethacin 75 MG Extended Release Oral Capsule"))
# f-146   (valueset (vs_name "nsaids") (code 311486) (label "meloxicam 7.5 MG Oral Tablet"))
# f-147   (valueset (vs_name "nsaids") (code 311892) (label "nabumetone 500 MG Oral Tablet"))
# f-148   (valueset (vs_name "nsaids") (code 311893) (label "nabumetone 750 MG Oral Tablet"))
# f-149   (valueset (vs_name "nsaids") (code 311913) (label "Naproxen 25 MG/ML Oral Suspension"))
# f-150   (valueset (vs_name "nsaids") (code 311915) (label "Naproxen 500 MG Delayed Release Oral Tablet"))
# f-151   (valueset (vs_name "nsaids") (code 312132) (label "oxaprozin 600 MG Oral Tablet"))
# f-152   (valueset (vs_name "nsaids") (code 312391) (label "Phenylbutazone 100 MG Oral Capsule"))
# f-153   (valueset (vs_name "nsaids") (code 312392) (label "Phenylbutazone 100 MG Oral Tablet"))
# f-154   (valueset (vs_name "nsaids") (code 312841) (label "rofecoxib 12.5 MG Oral Tablet"))
# f-155   (valueset (vs_name "nsaids") (code 312842) (label "rofecoxib 2.5 MG/ML Oral Suspension"))
# f-156   (valueset (vs_name "nsaids") (code 312843) (label "rofecoxib 5 MG/ML Oral Suspension"))
# f-157   (valueset (vs_name "nsaids") (code 312844) (label "rofecoxib 50 MG Oral Tablet"))
# f-158   (valueset (vs_name "nsaids") (code 314047) (label "Ibuprofen 50 MG Chewable Tablet"))
# f-159   (valueset (vs_name "nsaids") (code 314059) (label "24 HR Ketoprofen 100 MG Extended Release Oral Capsule"))
# f-160   (valueset (vs_name "nsaids") (code 314210) (label "rofecoxib 25 MG Oral Tablet"))
# f-161   (valueset (vs_name "nsaids") (code 346508) (label "Indomethacin 1 MG Injection"))
# f-162   (valueset (vs_name "nsaids") (code 349188) (label "oxaprozin 600 MG Delayed Release Oral Capsule"))
# f-163   (valueset (vs_name "nsaids") (code 349319) (label "valdecoxib 10 MG Oral Tablet"))
# f-164   (valueset (vs_name "nsaids") (code 349321) (label "valdecoxib 20 MG Oral Tablet"))
# f-165   (valueset (vs_name "nsaids") (code 349514) (label "celecoxib 400 MG Oral Capsule"))
# f-166   (valueset (vs_name "nsaids") (code 359500) (label "24 HR Etodolac 500 MG Extended Release Oral Tablet"))
# f-167   (valueset (vs_name "nsaids") (code 359697) (label "24 HR Ketoprofen 200 MG Extended Release Oral Capsule"))
# f-168   (valueset (vs_name "nsaids") (code 380813) (label "Ibuprofen 300 MG Extended Release Oral Capsule"))
# f-169   (valueset (vs_name "nsaids") (code 388519) (label "etoricoxib 60 MG Oral Tablet"))
# f-170   (valueset (vs_name "nsaids") (code 388520) (label "etoricoxib 90 MG Oral Tablet"))
# f-171   (valueset (vs_name "nsaids") (code 388521) (label "etoricoxib 120 MG Oral Tablet"))
# f-172   (valueset (vs_name "nsaids") (code 389243) (label "Dexketoprofen 25 MG Oral Tablet"))
# f-173   (valueset (vs_name "nsaids") (code 389247) (label "Flurbiprofen 8.75 MG Oral Lozenge"))
# f-174   (valueset (vs_name "nsaids") (code 392073) (label "Indomethacin 75 MG Oral Capsule"))
# f-175   (valueset (vs_name "nsaids") (code 392295) (label "fenbufen 200 MG Oral Capsule"))
# f-176   (valueset (vs_name "nsaids") (code 392296) (label "fenbufen 600 MG Oral Tablet"))
# f-177   (valueset (vs_name "nsaids") (code 392641) (label "nabumetone 2.5 MG/ML Oral Solution"))
# f-178   (valueset (vs_name "nsaids") (code 401933) (label "valdecoxib 40 MG Oral Tablet"))
# f-179   (valueset (vs_name "nsaids") (code 401976) (label "Ibuprofen 300 MG / Pseudoephedrine 45 MG Oral Capsule"))
# f-180   (valueset (vs_name "nsaids") (code 411846) (label "24 HR Diclofenac Sodium 100 MG Extended Release Oral Capsule"))
# f-181   (valueset (vs_name "nsaids") (code 411848) (label "24 HR Diclofenac Sodium 75 MG Extended Release Oral Capsule"))
# f-182   (valueset (vs_name "nsaids") (code 413132) (label "Dibucaine 2 MG/ML / Phenylbutazone 200 MG/ML Injectable Solution"))
# f-183   (valueset (vs_name "nsaids") (code 413640) (label "Phenylbutazone 200 MG/ML Injectable Solution"))
# f-184   (valueset (vs_name "nsaids") (code 427726) (label "nabumetone 1000 MG Oral Tablet"))
# f-185   (valueset (vs_name "nsaids") (code 429192) (label "Ketoprofen 25 MG Oral Tablet"))
# f-186   (valueset (vs_name "nsaids") (code 431823) (label "Ketoprofen 150 MG Extended Release Oral Tablet"))
# f-187   (valueset (vs_name "nsaids") (code 433845) (label "24 HR Naproxen 1000 MG Extended Release Oral Tablet"))
# f-188   (valueset (vs_name "nsaids") (code 597406) (label "meloxicam 1.5 MG/ML Oral Suspension"))
# f-189   (valueset (vs_name "nsaids") (code 603103) (label "Naproxen 375 MG Delayed Release Oral Tablet"))
# f-190   (valueset (vs_name "nsaids") (code 618552) (label "Meclofenamate 100 MG Oral Capsule"))
# f-191   (valueset (vs_name "nsaids") (code 618557) (label "Meclofenamate 50 MG Oral Capsule"))
# f-192   (valueset (vs_name "nsaids") (code 686379) (label "celecoxib 50 MG Oral Capsule"))
# f-193   (valueset (vs_name "nsaids") (code 834022) (label "Ketorolac Tromethamine 10 MG Oral Tablet"))
# f-194   (valueset (vs_name "nsaids") (code 849398) (label "Naproxen sodium 275 MG Oral Tablet"))
# f-195   (valueset (vs_name "nsaids") (code 849431) (label "Naproxen sodium 550 MG Oral Tablet"))
# f-196   (valueset (vs_name "nsaids") (code 849450) (label "Naproxen sodium 500 MG / Sumatriptan 85 MG Oral Tablet"))
# f-197   (valueset (vs_name "nsaids") (code 849574) (label "Naproxen sodium 220 MG Oral Tablet"))
# f-198   (valueset (vs_name "nsaids") (code 854183) (label "8 ML Ibuprofen 100 MG/ML Injection"))
# f-199   (valueset (vs_name "nsaids") (code 855626) (label "diclofenac epolamine 0.013 MG/MG Medicated Patch"))
# f-200   (valueset (vs_name "nsaids") (code 855657) (label "24 HR Diclofenac Sodium 100 MG Extended Release Oral Tablet"))
# f-201   (valueset (vs_name "nsaids") (code 855664) (label "Diclofenac Sodium 25 MG Delayed Release Oral Tablet"))
# f-202   (valueset (vs_name "nsaids") (code 855906) (label "Diclofenac Sodium 50 MG Delayed Release Oral Tablet"))
# f-203   (valueset (vs_name "nsaids") (code 855926) (label "Diclofenac Sodium 75 MG Delayed Release Oral Tablet"))
# f-204   (valueset (vs_name "nsaids") (code 855942) (label "Diclofenac Potassium 50 MG Oral Tablet"))
# f-205   (valueset (vs_name "nsaids") (code 857689) (label "Diclofenac Sodium 0.25 MG/ML Oral Solution"))
# f-206   (valueset (vs_name "nsaids") (code 857696) (label "Diclofenac Sodium 100 MG Rectal Suppository"))
# f-207   (valueset (vs_name "nsaids") (code 857698) (label "Diclofenac Sodium 12.5 MG Rectal Suppository"))
# f-208   (valueset (vs_name "nsaids") (code 857702) (label "Diclofenac Potassium 25 MG Oral Tablet"))
# f-209   (valueset (vs_name "nsaids") (code 857703) (label "Diclofenac Sodium 25 MG Rectal Suppository"))
# f-210   (valueset (vs_name "nsaids") (code 857705) (label "Diclofenac Sodium 25 MG/ML Injectable Solution"))
# f-211   (valueset (vs_name "nsaids") (code 857706) (label "Diclofenac Sodium 50 MG / Misoprostol 0.2 MG Delayed Release Oral Tablet"))
# f-212   (valueset (vs_name "nsaids") (code 857709) (label "Diclofenac Sodium 50 MG Rectal Suppository"))
# f-213   (valueset (vs_name "nsaids") (code 857713) (label "Diclofenac Sodium 75 MG Extended Release Oral Tablet"))
# f-214   (valueset (vs_name "nsaids") (code 858116) (label "Fenoprofen 400 MG Oral Capsule"))
# f-215   (valueset (vs_name "nsaids") (code 858342) (label "Diclofenac Potassium 25 MG Oral Capsule"))
# f-216   (valueset (vs_name "nsaids") (code 858770) (label "Hydrocodone Bitartrate 2.5 MG / Ibuprofen 200 MG Oral Tablet"))
# f-217   (valueset (vs_name "nsaids") (code 858778) (label "Hydrocodone Bitartrate 5 MG / Ibuprofen 200 MG Oral Tablet"))
# f-218   (valueset (vs_name "nsaids") (code 858798) (label "Hydrocodone Bitartrate 7.5 MG / Ibuprofen 200 MG Oral Tablet"))
# f-219   (valueset (vs_name "nsaids") (code 859063) (label "Diclofenac Potassium 50 MG Powder for Oral Solution"))
# f-220   (valueset (vs_name "nsaids") (code 859315) (label "Hydrocodone Bitartrate 10 MG / Ibuprofen 200 MG Oral Tablet"))
# f-221   (valueset (vs_name "nsaids") (code 860092) (label "1 ML Ketorolac Tromethamine 15 MG/ML Injection"))
# f-222   (valueset (vs_name "nsaids") (code 860096) (label "Ketorolac Tromethamine 30 MG/ML Injectable Solution"))
# f-223   (valueset (vs_name "nsaids") (code 860113) (label "1 ML Ketorolac Tromethamine 15 MG/ML Prefilled Syringe"))
# f-224   (valueset (vs_name "nsaids") (code 860114) (label "1 ML Ketorolac Tromethamine 30 MG/ML Prefilled Syringe"))
# f-225   (valueset (vs_name "nsaids") (code 860115) (label "2 ML Ketorolac Tromethamine 30 MG/ML Prefilled Syringe"))
# f-226   (valueset (vs_name "nsaids") (code 861846) (label "Ketorolac Tromethamine 10 MG/ML Injectable Solution"))
# f-227   (valueset (vs_name "nsaids") (code 895664) (label "Diphenhydramine Citrate 38 MG / Ibuprofen 200 MG Oral Tablet"))
# f-228   (valueset (vs_name "nsaids") (code 901814) (label "Diphenhydramine Hydrochloride 25 MG / Ibuprofen 200 MG Oral Capsule"))
# f-229   (valueset (vs_name "nsaids") (code 994005) (label "Esomeprazole 20 MG / Naproxen 375 MG Delayed Release Oral Tablet"))
# f-230   (valueset (vs_name "nsaids") (code 994008) (label "Esomeprazole 20 MG / Naproxen 500 MG Delayed Release Oral Tablet"))
# f-231   (valueset (vs_name "nsaids") (code 997164) (label "Codeine Phosphate 12.5 MG / Ibuprofen 200 MG Oral Tablet"))
# f-232   (valueset (vs_name "nsaids") (code 997165) (label "Codeine Phosphate 12.8 MG / Ibuprofen 200 MG Oral Tablet"))
# f-233   (valueset (vs_name "nsaids") (code 997280) (label "Codeine Phosphate 20 MG / Ibuprofen 300 MG Extended Release Oral Tablet"))
# f-234   (valueset (vs_name "SSRI_SNRI") (code 1086772) (label "vilazodone hydrochloride 10 MG Oral Tablet"))
# f-235   (valueset (vs_name "SSRI_SNRI") (code 1086778) (label "vilazodone hydrochloride 20 MG Oral Tablet"))
# f-236   (valueset (vs_name "SSRI_SNRI") (code 1086784) (label "vilazodone hydrochloride 40 MG Oral Tablet"))
# f-237   (valueset (vs_name "SSRI_SNRI") (code 1190110) (label "Fluoxetine 60 MG Oral Tablet"))
# f-238   (valueset (vs_name "SSRI_SNRI") (code 1430122) (label "Paroxetine mesylate 7.5 MG Oral Capsule"))
# f-239   (valueset (vs_name "SSRI_SNRI") (code 1433217) (label "24 HR levomilnacipran 120 MG Extended Release Oral Capsule"))
# f-240   (valueset (vs_name "SSRI_SNRI") (code 1433227) (label "24 HR levomilnacipran 20 MG Extended Release Oral Capsule"))
# f-241   (valueset (vs_name "SSRI_SNRI") (code 1433233) (label "24 HR levomilnacipran 40 MG Extended Release Oral Capsule"))
# f-242   (valueset (vs_name "SSRI_SNRI") (code 1433239) (label "24 HR levomilnacipran 80 MG Extended Release Oral Capsule"))
# f-243   (valueset (vs_name "SSRI_SNRI") (code 1439808) (label "vortioxetine 10 MG Oral Tablet"))
# f-244   (valueset (vs_name "SSRI_SNRI") (code 1439810) (label "vortioxetine 20 MG Oral Tablet"))
# f-245   (valueset (vs_name "SSRI_SNRI") (code 1439812) (label "vortioxetine 5 MG Oral Tablet"))
# f-246   (valueset (vs_name "SSRI_SNRI") (code 1439840) (label "vortioxetine 15 MG Oral Tablet"))
# f-247   (valueset (vs_name "SSRI_SNRI") (code 151260) (label "Fluoxetine 60 MG Oral Capsule"))
# f-248   (valueset (vs_name "SSRI_SNRI") (code 1607617) (label "24 HR desvenlafaxine succinate 25 MG Extended Release Oral Tablet"))
# f-249   (valueset (vs_name "SSRI_SNRI") (code 199990) (label "Sertraline 25 MG Oral Capsule"))
# f-250   (valueset (vs_name "SSRI_SNRI") (code 200371) (label "Citalopram 20 MG Oral Tablet"))
# f-251   (valueset (vs_name "SSRI_SNRI") (code 248097) (label "Sertraline 50 MG Oral Capsule"))
# f-252   (valueset (vs_name "SSRI_SNRI") (code 248098) (label "Sertraline 100 MG Oral Capsule"))
# f-253   (valueset (vs_name "SSRI_SNRI") (code 248642) (label "Fluoxetine 20 MG Oral Tablet"))
# f-254   (valueset (vs_name "SSRI_SNRI") (code 251200) (label "Sertraline 200 MG Oral Tablet"))
# f-255   (valueset (vs_name "SSRI_SNRI") (code 283672) (label "Citalopram 10 MG Oral Tablet"))
# f-256   (valueset (vs_name "SSRI_SNRI") (code 309313) (label "Citalopram 2 MG/ML Oral Solution"))
# f-257   (valueset (vs_name "SSRI_SNRI") (code 309314) (label "Citalopram 40 MG Oral Tablet"))
# f-258   (valueset (vs_name "SSRI_SNRI") (code 310384) (label "Fluoxetine 10 MG Oral Capsule"))
# f-259   (valueset (vs_name "SSRI_SNRI") (code 310385) (label "Fluoxetine 20 MG Oral Capsule"))
# f-260   (valueset (vs_name "SSRI_SNRI") (code 310386) (label "Fluoxetine 4 MG/ML Oral Solution"))
# f-261   (valueset (vs_name "SSRI_SNRI") (code 312242) (label "Paroxetine Hydrochloride 2 MG/ML Oral Suspension"))
# f-262   (valueset (vs_name "SSRI_SNRI") (code 312938) (label "Sertraline 100 MG Oral Tablet"))
# f-263   (valueset (vs_name "SSRI_SNRI") (code 312940) (label "Sertraline 25 MG Oral Tablet"))
# f-264   (valueset (vs_name "SSRI_SNRI") (code 312941) (label "Sertraline 50 MG Oral Tablet"))
# f-265   (valueset (vs_name "SSRI_SNRI") (code 313580) (label "venlafaxine 100 MG Oral Tablet"))
# f-266   (valueset (vs_name "SSRI_SNRI") (code 313581) (label "24 HR venlafaxine 150 MG Extended Release Oral Capsule"))
# f-267   (valueset (vs_name "SSRI_SNRI") (code 313582) (label "venlafaxine 25 MG Oral Tablet"))
# f-268   (valueset (vs_name "SSRI_SNRI") (code 313583) (label "24 HR venlafaxine 37.5 MG Extended Release Oral Capsule"))
# f-269   (valueset (vs_name "SSRI_SNRI") (code 313584) (label "venlafaxine 37.5 MG Oral Tablet"))
# f-270   (valueset (vs_name "SSRI_SNRI") (code 313585) (label "24 HR venlafaxine 75 MG Extended Release Oral Capsule"))
# f-271   (valueset (vs_name "SSRI_SNRI") (code 313586) (label "venlafaxine 75 MG Oral Tablet"))
# f-272   (valueset (vs_name "SSRI_SNRI") (code 313989) (label "Fluoxetine 40 MG Oral Capsule"))
# f-273   (valueset (vs_name "SSRI_SNRI") (code 313990) (label "Fluoxetine 10 MG Oral Tablet"))
# f-274   (valueset (vs_name "SSRI_SNRI") (code 313995) (label "Fluoxetine 90 MG Delayed Release Oral Capsule"))
# f-275   (valueset (vs_name "SSRI_SNRI") (code 314277) (label "venlafaxine 50 MG Oral Tablet"))
# f-276   (valueset (vs_name "SSRI_SNRI") (code 349332) (label "Escitalopram 10 MG Oral Tablet"))
# f-277   (valueset (vs_name "SSRI_SNRI") (code 351249) (label "Escitalopram 5 MG Oral Tablet"))
# f-278   (valueset (vs_name "SSRI_SNRI") (code 351250) (label "Escitalopram 20 MG Oral Tablet"))
# f-279   (valueset (vs_name "SSRI_SNRI") (code 351285) (label "Escitalopram 1 MG/ML Oral Solution"))
# f-280   (valueset (vs_name "SSRI_SNRI") (code 389202) (label "Citalopram 40 MG/ML Oral Solution"))
# f-281   (valueset (vs_name "SSRI_SNRI") (code 403969) (label "Fluoxetine 25 MG / olanzapine 6 MG Oral Capsule"))
# f-282   (valueset (vs_name "SSRI_SNRI") (code 403970) (label "Fluoxetine 25 MG / olanzapine 12 MG Oral Capsule"))
# f-283   (valueset (vs_name "SSRI_SNRI") (code 403971) (label "Fluoxetine 50 MG / olanzapine 12 MG Oral Capsule"))
# f-284   (valueset (vs_name "SSRI_SNRI") (code 403972) (label "Fluoxetine 50 MG / olanzapine 6 MG Oral Capsule"))
# f-285   (valueset (vs_name "SSRI_SNRI") (code 411805) (label "24 HR venlafaxine 100 MG Extended Release Oral Capsule"))
# f-286   (valueset (vs_name "SSRI_SNRI") (code 596926) (label "duloxetine 20 MG Delayed Release Oral Capsule"))
# f-287   (valueset (vs_name "SSRI_SNRI") (code 596930) (label "duloxetine 30 MG Delayed Release Oral Capsule"))
# f-288   (valueset (vs_name "SSRI_SNRI") (code 596934) (label "duloxetine 60 MG Delayed Release Oral Capsule"))
# f-289   (valueset (vs_name "SSRI_SNRI") (code 616402) (label "duloxetine 40 MG Delayed Release Oral Capsule"))
# f-290   (valueset (vs_name "SSRI_SNRI") (code 645289) (label "Citalopram 10 MG Disintegrating Oral Tablet"))
# f-291   (valueset (vs_name "SSRI_SNRI") (code 645290) (label "Citalopram 20 MG Disintegrating Oral Tablet"))
# f-292   (valueset (vs_name "SSRI_SNRI") (code 645291) (label "Citalopram 40 MG Disintegrating Oral Tablet"))
# f-293   (valueset (vs_name "SSRI_SNRI") (code 721787) (label "Fluoxetine 25 MG / olanzapine 3 MG Oral Capsule"))
# f-294   (valueset (vs_name "SSRI_SNRI") (code 790264) (label "24 HR Desvenlafaxine 100 MG Extended Release Oral Tablet"))
# f-295   (valueset (vs_name "SSRI_SNRI") (code 790288) (label "24 HR Desvenlafaxine 50 MG Extended Release Oral Tablet"))
# f-296   (valueset (vs_name "SSRI_SNRI") (code 794947) (label "Sertraline 150 MG Oral Tablet"))
# f-297   (valueset (vs_name "SSRI_SNRI") (code 803408) (label "Desvenlafaxine 100 MG Oral Tablet"))
# f-298   (valueset (vs_name "SSRI_SNRI") (code 803409) (label "Desvenlafaxine 50 MG Oral Tablet"))
# f-299   (valueset (vs_name "SSRI_SNRI") (code 808744) (label "24 HR venlafaxine 150 MG Extended Release Oral Tablet"))
# f-300   (valueset (vs_name "SSRI_SNRI") (code 808748) (label "24 HR venlafaxine 225 MG Extended Release Oral Tablet"))
# f-301   (valueset (vs_name "SSRI_SNRI") (code 808751) (label "24 HR venlafaxine 37.5 MG Extended Release Oral Tablet"))
# f-302   (valueset (vs_name "SSRI_SNRI") (code 808753) (label "24 HR venlafaxine 75 MG Extended Release Oral Tablet"))
# f-303   (valueset (vs_name "SSRI_SNRI") (code 826098) (label "Fluoxetine Hydrochloride 8 MG Chewable Tablet"))
# f-304   (valueset (vs_name "SSRI_SNRI") (code 826103) (label "Fluoxetine Hydrochloride 64 MG Chewable Tablet"))
# f-305   (valueset (vs_name "SSRI_SNRI") (code 833135) (label "Milnacipran hydrochloride 100 MG Oral Tablet"))
# f-306   (valueset (vs_name "SSRI_SNRI") (code 833141) (label "Milnacipran hydrochloride 12.5 MG Oral Tablet"))
# f-307   (valueset (vs_name "SSRI_SNRI") (code 833144) (label "Milnacipran hydrochloride 50 MG Oral Tablet"))
# f-308   (valueset (vs_name "SSRI_SNRI") (code 833147) (label "Milnacipran hydrochloride 25 MG Oral Tablet"))
# f-309   (valueset (vs_name "SSRI_SNRI") (code 835564) (label "Imipramine Hydrochloride 25 MG Oral Tablet"))
# f-310   (valueset (vs_name "SSRI_SNRI") (code 835568) (label "Imipramine Hydrochloride 50 MG Oral Tablet"))
# f-311   (valueset (vs_name "SSRI_SNRI") (code 835572) (label "Imipramine pamoate 75 MG Oral Capsule"))
# f-312   (valueset (vs_name "SSRI_SNRI") (code 835577) (label "Imipramine pamoate 150 MG Oral Capsule"))
# f-313   (valueset (vs_name "SSRI_SNRI") (code 835586) (label "Imipramine Hydrochloride 5 MG/ML Oral Solution"))
# f-314   (valueset (vs_name "SSRI_SNRI") (code 835589) (label "Imipramine pamoate 125 MG Oral Capsule"))
# f-315   (valueset (vs_name "SSRI_SNRI") (code 835591) (label "Imipramine pamoate 100 MG Oral Capsule"))
# f-316   (valueset (vs_name "SSRI_SNRI") (code 835593) (label "Imipramine Hydrochloride 10 MG Oral Tablet"))
# f-317   (valueset (vs_name "SSRI_SNRI") (code 856364) (label "Trazodone Hydrochloride 150 MG Oral Tablet"))
# f-318   (valueset (vs_name "SSRI_SNRI") (code 856369) (label "Trazodone Hydrochloride 300 MG Oral Tablet"))
# f-319   (valueset (vs_name "SSRI_SNRI") (code 856373) (label "Trazodone Hydrochloride 100 MG Oral Tablet"))
# f-320   (valueset (vs_name "SSRI_SNRI") (code 856377) (label "Trazodone Hydrochloride 50 MG Oral Tablet"))
# f-321   (valueset (vs_name "SSRI_SNRI") (code 856382) (label "Trazodone Hydrochloride 100 MG Oral Capsule"))
# f-322   (valueset (vs_name "SSRI_SNRI") (code 856383) (label "Trazodone Hydrochloride 50 MG Oral Capsule"))
# f-323   (valueset (vs_name "SSRI_SNRI") (code 857289) (label "Clomipramine Hydrochloride 12.5 MG/ML Injectable Solution"))
# f-324   (valueset (vs_name "SSRI_SNRI") (code 857291) (label "Clomipramine Hydrochloride 10 MG Oral Tablet"))
# f-325   (valueset (vs_name "SSRI_SNRI") (code 857292) (label "Clomipramine Hydrochloride 10 MG Oral Capsule"))
# f-326   (valueset (vs_name "SSRI_SNRI") (code 857296) (label "Clomipramine Hydrochloride 25 MG Oral Tablet"))
# f-327   (valueset (vs_name "SSRI_SNRI") (code 857297) (label "Clomipramine Hydrochloride 25 MG Oral Capsule"))
# f-328   (valueset (vs_name "SSRI_SNRI") (code 857301) (label "Clomipramine Hydrochloride 50 MG Oral Capsule"))
# f-329   (valueset (vs_name "SSRI_SNRI") (code 857305) (label "Clomipramine Hydrochloride 75 MG Oral Capsule"))
# f-330   (valueset (vs_name "SSRI_SNRI") (code 857315) (label "Clomipramine Hydrochloride 50 MG Oral Tablet"))
# f-331   (valueset (vs_name "SSRI_SNRI") (code 857326) (label "Clomipramine Hydrochloride 75 MG Extended Release Oral Tablet"))
# f-332   (valueset (vs_name "SSRI_SNRI") (code 861064) (label "Sertraline 20 MG/ML Oral Solution"))
# f-333   (valueset (vs_name "SSRI_SNRI") (code 892742) (label "Clomipramine Hydrochloride 20 MG Oral Tablet"))
# f-334   (valueset (vs_name "SSRI_SNRI") (code 894759) (label "Clomipramine Hydrochloride 5 MG Oral Tablet"))
# f-335   (valueset (vs_name "SSRI_SNRI") (code 894763) (label "Clomipramine Hydrochloride 80 MG Oral Tablet"))
# f-336   (valueset (vs_name "SSRI_SNRI") (code 898697) (label "24 HR Trazodone Hydrochloride 150 MG Extended Release Oral Tablet"))
# f-337   (valueset (vs_name "SSRI_SNRI") (code 898704) (label "24 HR Trazodone Hydrochloride 300 MG Extended Release Oral Tablet"))
# f-338   (valueset (vs_name "SSRI_SNRI") (code 902714) (label "Fluoxetine Hydrochloride 16 MG Chewable Tablet"))
# f-339   (valueset (vs_name "SSRI_SNRI") (code 902718) (label "Fluoxetine Hydrochloride 32 MG Chewable Tablet"))
# f-340   (valueset (vs_name "SSRI_SNRI") (code 903873) (label "24 HR Fluvoxamine Maleate 100 MG Extended Release Oral Capsule"))
# f-341   (valueset (vs_name "SSRI_SNRI") (code 903879) (label "24 HR Fluvoxamine Maleate 150 MG Extended Release Oral Capsule"))
# f-342   (valueset (vs_name "SSRI_SNRI") (code 903884) (label "Fluvoxamine Maleate 100 MG Oral Tablet"))
# f-343   (valueset (vs_name "SSRI_SNRI") (code 903887) (label "Fluvoxamine Maleate 25 MG Oral Tablet"))
# f-344   (valueset (vs_name "SSRI_SNRI") (code 903891) (label "Fluvoxamine Maleate 50 MG Oral Tablet"))
# f-345   (valueset (vs_name "systemic_corticosteriods") (code 1012221) (label "hydrocortisone acetate 0.0055 MG/MG / Lidocaine Hydrochloride 0.028 MG/MG Rectal Gel"))
# f-346   (valueset (vs_name "systemic_corticosteriods") (code 1012223) (label "hydrocortisone acetate 0.025 MG/MG / Lidocaine Hydrochloride 0.03 MG/MG Rectal Gel"))
# f-347   (valueset (vs_name "systemic_corticosteriods") (code 1012229) (label "hydrocortisone acetate 10 MG/ML / Lidocaine Hydrochloride 30 MG/ML Rectal Cream"))
# f-348   (valueset (vs_name "systemic_corticosteriods") (code 1012233) (label "hydrocortisone acetate 20 MG/ML / Lidocaine Hydrochloride 20 MG/ML Rectal Cream"))
# f-349   (valueset (vs_name "systemic_corticosteriods") (code 1012235) (label "hydrocortisone acetate 5 MG/ML / Lidocaine Hydrochloride 30 MG/ML Rectal Cream"))
# f-350   (valueset (vs_name "systemic_corticosteriods") (code 1085728) (label "Triamcinolone Acetonide 0.001 MG/MG Oral Paste"))
# f-351   (valueset (vs_name "systemic_corticosteriods") (code 1085750) (label "Triamcinolone Acetonide 10 MG/ML Injectable Suspension"))
# f-352   (valueset (vs_name "systemic_corticosteriods") (code 1085754) (label "Triamcinolone Acetonide 40 MG/ML Injectable Suspension"))
# f-353   (valueset (vs_name "systemic_corticosteriods") (code 1085992) (label "triamcinolone hexacetonide 5 MG/ML Injectable Suspension"))
# f-354   (valueset (vs_name "systemic_corticosteriods") (code 1085996) (label "triamcinolone hexacetonide 20 MG/ML Injectable Suspension"))
# f-355   (valueset (vs_name "systemic_corticosteriods") (code 1094443) (label "hydrocortisone acetate 23.5 MG/ML / Pramoxine hydrochloride 10 MG/ML Rectal Cream"))
# f-356   (valueset (vs_name "systemic_corticosteriods") (code 1114854) (label "hydrocortisone acetate 18.5 MG/ML / Pramoxine hydrochloride 11.5 MG/ML Rectal Cream"))
# f-357   (valueset (vs_name "systemic_corticosteriods") (code 1116927) (label "Dexamethasone phosphate 4 MG/ML Injectable Solution"))
# f-358   (valueset (vs_name "systemic_corticosteriods") (code 1235049) (label "hydrocortisone acetate 10 MG/ML / Pramoxine hydrochloride 10 MG/ML Rectal Cream"))
# f-359   (valueset (vs_name "systemic_corticosteriods") (code 1246528) (label "Hydrocortisone 25 MG/ML / Pramoxine hydrochloride 10 MG/ML Rectal Cream"))
# f-360   (valueset (vs_name "systemic_corticosteriods") (code 1291082) (label "hydrocortisone acetate 25 MG Rectal Suppository"))
# f-361   (valueset (vs_name "systemic_corticosteriods") (code 1291085) (label "hydrocortisone acetate 30 MG Rectal Suppository"))
# f-362   (valueset (vs_name "systemic_corticosteriods") (code 1294025) (label "hydrocortisone acetate 25 MG/ML / Pramoxine hydrochloride 10 MG/ML Rectal Cream"))
# f-363   (valueset (vs_name "systemic_corticosteriods") (code 1303125) (label "Prednisone 1 MG Delayed Release Oral Tablet"))
# f-364   (valueset (vs_name "systemic_corticosteriods") (code 1303132) (label "Prednisone 2 MG Delayed Release Oral Tablet"))
# f-365   (valueset (vs_name "systemic_corticosteriods") (code 1303135) (label "Prednisone 5 MG Delayed Release Oral Tablet"))
# f-366   (valueset (vs_name "systemic_corticosteriods") (code 1357886) (label "Methylprednisolone 2000 MG Injection"))
# f-367   (valueset (vs_name "systemic_corticosteriods") (code 1358510) (label "methylprednisolone acetate 20 MG/ML Injectable Suspension"))
# f-368   (valueset (vs_name "systemic_corticosteriods") (code 1358610) (label "methylprednisolone acetate 40 MG/ML Injectable Suspension"))
# f-369   (valueset (vs_name "systemic_corticosteriods") (code 1358617) (label "methylprednisolone acetate 80 MG/ML Injectable Suspension"))
# f-370   (valueset (vs_name "systemic_corticosteriods") (code 1494032) (label "Hydrocortisone 10 MG/ML Vaginal Cream"))
# f-371   (valueset (vs_name "systemic_corticosteriods") (code 1545172) (label "hydrocortisone acetate 100 MG/ML Rectal Foam"))
# f-372   (valueset (vs_name "systemic_corticosteriods") (code 197543) (label "Cortisone 10 MG Oral Tablet"))
# f-373   (valueset (vs_name "systemic_corticosteriods") (code 197545) (label "Cortisone 5 MG Oral Tablet"))
# f-374   (valueset (vs_name "systemic_corticosteriods") (code 197577) (label "Dexamethasone 0.5 MG Oral Tablet"))
# f-375   (valueset (vs_name "systemic_corticosteriods") (code 197579) (label "Dexamethasone 1 MG Oral Tablet"))
# f-376   (valueset (vs_name "systemic_corticosteriods") (code 197580) (label "Dexamethasone 1.5 MG Oral Tablet"))
# f-377   (valueset (vs_name "systemic_corticosteriods") (code 197581) (label "Dexamethasone 2 MG Oral Tablet"))
# f-378   (valueset (vs_name "systemic_corticosteriods") (code 197582) (label "Dexamethasone 4 MG Oral Tablet"))
# f-379   (valueset (vs_name "systemic_corticosteriods") (code 197583) (label "Dexamethasone 6 MG Oral Tablet"))
# f-380   (valueset (vs_name "systemic_corticosteriods") (code 197782) (label "Hydrocortisone 10 MG Oral Tablet"))
# f-381   (valueset (vs_name "systemic_corticosteriods") (code 197783) (label "Hydrocortisone 20 MG Oral Tablet"))
# f-382   (valueset (vs_name "systemic_corticosteriods") (code 197787) (label "Hydrocortisone 5 MG Oral Tablet"))
# f-383   (valueset (vs_name "systemic_corticosteriods") (code 197969) (label "Methylprednisolone 2 MG Oral Tablet"))
# f-384   (valueset (vs_name "systemic_corticosteriods") (code 197971) (label "Methylprednisolone 32 MG Oral Tablet"))
# f-385   (valueset (vs_name "systemic_corticosteriods") (code 197973) (label "Methylprednisolone 8 MG Oral Tablet"))
# f-386   (valueset (vs_name "systemic_corticosteriods") (code 198142) (label "prednisolone 5 MG Oral Tablet"))
# f-387   (valueset (vs_name "systemic_corticosteriods") (code 198144) (label "Prednisone 1 MG Oral Tablet"))
# f-388   (valueset (vs_name "systemic_corticosteriods") (code 198145) (label "Prednisone 10 MG Oral Tablet"))
# f-389   (valueset (vs_name "systemic_corticosteriods") (code 198146) (label "Prednisone 2.5 MG Oral Tablet"))
# f-390   (valueset (vs_name "systemic_corticosteriods") (code 198148) (label "Prednisone 50 MG Oral Tablet"))
# f-391   (valueset (vs_name "systemic_corticosteriods") (code 198301) (label "Triamcinolone 1 MG Oral Tablet"))
# f-392   (valueset (vs_name "systemic_corticosteriods") (code 199320) (label "Hydrocortisone 4 MG Oral Tablet"))
# f-393   (valueset (vs_name "systemic_corticosteriods") (code 199343) (label "prednisolone 1 MG Oral Tablet"))
# f-394   (valueset (vs_name "systemic_corticosteriods") (code 199771) (label "Methylprednisolone 100 MG Oral Tablet"))
# f-395   (valueset (vs_name "systemic_corticosteriods") (code 199967) (label "prednisolone 25 MG Oral Tablet"))
# f-396   (valueset (vs_name "systemic_corticosteriods") (code 205301) (label "Prednisone 5 MG/ML Oral Solution"))
# f-397   (valueset (vs_name "systemic_corticosteriods") (code 238755) (label "Hydrocortisone 100 MG Injection"))
# f-398   (valueset (vs_name "systemic_corticosteriods") (code 249066) (label "prednisolone 5 MG/ML Oral Solution"))
# f-399   (valueset (vs_name "systemic_corticosteriods") (code 259966) (label "Methylprednisolone 4 MG Oral Tablet"))
# f-400   (valueset (vs_name "systemic_corticosteriods") (code 260192) (label "Hydrocortisone 0.01 MG/MG Rectal Ointment"))
# f-401   (valueset (vs_name "systemic_corticosteriods") (code 283077) (label "prednisolone 3 MG/ML Oral Solution"))
# f-402   (valueset (vs_name "systemic_corticosteriods") (code 308709) (label "Betamethasone 0.6 MG Oral Tablet"))
# f-403   (valueset (vs_name "systemic_corticosteriods") (code 309684) (label "Dexamethasone 1 MG/ML Oral Solution"))
# f-404   (valueset (vs_name "systemic_corticosteriods") (code 309686) (label "Dexamethasone 0.1 MG/ML Oral Solution"))
# f-405   (valueset (vs_name "systemic_corticosteriods") (code 309696) (label "Dexamethasone phosphate 10 MG/ML Injectable Solution"))
# f-406   (valueset (vs_name "systemic_corticosteriods") (code 310868) (label "Hydrocortisone 10 MG/ML Rectal Cream"))
# f-407   (valueset (vs_name "systemic_corticosteriods") (code 310878) (label "Hydrocortisone 1.67 MG/ML Enema"))
# f-408   (valueset (vs_name "systemic_corticosteriods") (code 310879) (label "Hydrocortisone 25 MG/ML Rectal Cream"))
# f-409   (valueset (vs_name "systemic_corticosteriods") (code 310899) (label "Hydrocortisone 2 MG/ML Oral Suspension"))
# f-410   (valueset (vs_name "systemic_corticosteriods") (code 311659) (label "Methylprednisolone 40 MG Injection"))
# f-411   (valueset (vs_name "systemic_corticosteriods") (code 312614) (label "prednisolone 1 MG/ML Oral Solution"))
# f-412   (valueset (vs_name "systemic_corticosteriods") (code 312615) (label "Prednisone 20 MG Oral Tablet"))
# f-413   (valueset (vs_name "systemic_corticosteriods") (code 312617) (label "Prednisone 5 MG Oral Tablet"))
# f-414   (valueset (vs_name "systemic_corticosteriods") (code 313979) (label "Fludrocortisone 0.1 MG Oral Tablet"))
# f-415   (valueset (vs_name "systemic_corticosteriods") (code 314099) (label "Methylprednisolone 62.5 MG/ML Injectable Solution"))
# f-416   (valueset (vs_name "systemic_corticosteriods") (code 315187) (label "Prednisone 1 MG/ML Oral Solution"))
# f-417   (valueset (vs_name "systemic_corticosteriods") (code 328161) (label "Methylprednisolone 16 MG Oral Tablet"))
# f-418   (valueset (vs_name "systemic_corticosteriods") (code 343033) (label "Dexamethasone 0.75 MG Oral Tablet"))
# f-419   (valueset (vs_name "systemic_corticosteriods") (code 429199) (label "prednisolone 20 MG Oral Tablet"))
# f-420   (valueset (vs_name "systemic_corticosteriods") (code 578803) (label "Betamethasone 3 MG/ML / Betamethasone acetate 3 MG/ML Injectable Suspension"))
# f-421   (valueset (vs_name "systemic_corticosteriods") (code 643123) (label "prednisolone 10 MG Disintegrating Oral Tablet"))
# f-422   (valueset (vs_name "systemic_corticosteriods") (code 643125) (label "prednisolone 15 MG Disintegrating Oral Tablet"))
# f-423   (valueset (vs_name "systemic_corticosteriods") (code 643127) (label "prednisolone 30 MG Disintegrating Oral Tablet"))
# f-424   (valueset (vs_name "systemic_corticosteriods") (code 670084) (label "Betamethasone 0.12 MG/ML Oral Solution"))
# f-425   (valueset (vs_name "systemic_corticosteriods") (code 702306) (label "prednisolone 4 MG/ML Oral Solution"))
# f-426   (valueset (vs_name "systemic_corticosteriods") (code 793099) (label "prednisolone 3 MG/ML Oral Suspension"))
# f-427   (valueset (vs_name "systemic_corticosteriods") (code 794979) (label "prednisolone 2 MG/ML Oral Solution"))
# f-428   (valueset (vs_name "systemic_corticosteriods") (code 828248) (label "cortisone acetate 25 MG Oral Tablet"))
# f-429   (valueset (vs_name "systemic_corticosteriods") (code 828362) (label "hydrocortisone acetate 10 MG/ML / Pramoxine hydrochloride 10 MG/ML Rectal Foam"))
# f-430   (valueset (vs_name "systemic_corticosteriods") (code 854177) (label "Dexamethasone 0.7 MG Drug Implant"))
# f-431   (valueset (vs_name "tricyclic_antidepressants") (code 1000048) (label "Doxepin Hydrochloride 10 MG Oral Capsule"))
# f-432   (valueset (vs_name "tricyclic_antidepressants") (code 1000054) (label "Doxepin Hydrochloride 10 MG/ML Oral Solution"))
# f-433   (valueset (vs_name "tricyclic_antidepressants") (code 1000058) (label "Doxepin Hydrochloride 100 MG Oral Capsule"))
# f-434   (valueset (vs_name "tricyclic_antidepressants") (code 1000064) (label "Doxepin Hydrochloride 150 MG Oral Capsule"))
# f-435   (valueset (vs_name "tricyclic_antidepressants") (code 1000070) (label "Doxepin Hydrochloride 25 MG Oral Capsule"))
# f-436   (valueset (vs_name "tricyclic_antidepressants") (code 1000076) (label "Doxepin Hydrochloride 50 MG Oral Capsule"))
# f-437   (valueset (vs_name "tricyclic_antidepressants") (code 1000091) (label "Doxepin Hydrochloride 50 MG/ML Topical Cream"))
# f-438   (valueset (vs_name "tricyclic_antidepressants") (code 1000097) (label "Doxepin Hydrochloride 75 MG Oral Capsule"))
# f-439   (valueset (vs_name "tricyclic_antidepressants") (code 1099288) (label "Desipramine Hydrochloride 10 MG Oral Tablet"))
# f-440   (valueset (vs_name "tricyclic_antidepressants") (code 1099292) (label "Desipramine Hydrochloride 100 MG Oral Tablet"))
# f-441   (valueset (vs_name "tricyclic_antidepressants") (code 1099296) (label "Desipramine Hydrochloride 150 MG Oral Tablet"))
# f-442   (valueset (vs_name "tricyclic_antidepressants") (code 1099300) (label "Desipramine Hydrochloride 25 MG Oral Tablet"))
# f-443   (valueset (vs_name "tricyclic_antidepressants") (code 1099304) (label "Desipramine Hydrochloride 50 MG Oral Tablet"))
# f-444   (valueset (vs_name "tricyclic_antidepressants") (code 1099316) (label "Desipramine Hydrochloride 75 MG Oral Tablet"))
# f-445   (valueset (vs_name "tricyclic_antidepressants") (code 1298803) (label "Maprotiline Hydrochloride 10 MG Oral Tablet"))
# f-446   (valueset (vs_name "tricyclic_antidepressants") (code 1298857) (label "Maprotiline Hydrochloride 25 MG Oral Tablet"))
# f-447   (valueset (vs_name "tricyclic_antidepressants") (code 1298861) (label "Maprotiline Hydrochloride 50 MG Oral Tablet"))
# f-448   (valueset (vs_name "tricyclic_antidepressants") (code 1298870) (label "Maprotiline Hydrochloride 75 MG Oral Tablet"))
# f-449   (valueset (vs_name "tricyclic_antidepressants") (code 197363) (label "Amoxapine 100 MG Oral Tablet"))
# f-450   (valueset (vs_name "tricyclic_antidepressants") (code 197364) (label "Amoxapine 150 MG Oral Tablet"))
# f-451   (valueset (vs_name "tricyclic_antidepressants") (code 197365) (label "Amoxapine 25 MG Oral Tablet"))
# f-452   (valueset (vs_name "tricyclic_antidepressants") (code 197366) (label "Amoxapine 50 MG Oral Tablet"))
# f-453   (valueset (vs_name "tricyclic_antidepressants") (code 198045) (label "Nortriptyline 10 MG Oral Capsule"))
# f-454   (valueset (vs_name "tricyclic_antidepressants") (code 198046) (label "Nortriptyline 50 MG Oral Capsule"))
# f-455   (valueset (vs_name "tricyclic_antidepressants") (code 198047) (label "Nortriptyline 75 MG Oral Capsule"))
# f-456   (valueset (vs_name "tricyclic_antidepressants") (code 199283) (label "Nortriptyline 10 MG Oral Tablet"))
# f-457   (valueset (vs_name "tricyclic_antidepressants") (code 199406) (label "Nortriptyline 25 MG Oral Tablet"))
# f-458   (valueset (vs_name "tricyclic_antidepressants") (code 199820) (label "Trimipramine 25 MG Oral Tablet"))
# f-459   (valueset (vs_name "tricyclic_antidepressants") (code 199945) (label "Doxepin 75 MG Oral Tablet"))
# f-460   (valueset (vs_name "tricyclic_antidepressants") (code 245372) (label "Trimipramine 12.5 MG Oral Tablet"))
# f-461   (valueset (vs_name "tricyclic_antidepressants") (code 245373) (label "Trimipramine 50 MG Oral Tablet"))
# f-462   (valueset (vs_name "tricyclic_antidepressants") (code 245374) (label "Trimipramine 75 MG Oral Capsule"))
# f-463   (valueset (vs_name "tricyclic_antidepressants") (code 245388) (label "Amitriptyline 15 MG / Perphenazine 3 MG Oral Tablet"))
# f-464   (valueset (vs_name "tricyclic_antidepressants") (code 249706) (label "Lofepramine 70 MG Oral Tablet"))
# f-465   (valueset (vs_name "tricyclic_antidepressants") (code 250033) (label "Trimipramine 10 MG Oral Tablet"))
# f-466   (valueset (vs_name "tricyclic_antidepressants") (code 250722) (label "Lofepramine 14 MG/ML Oral Suspension"))
# f-467   (valueset (vs_name "tricyclic_antidepressants") (code 312036) (label "Nortriptyline 2 MG/ML Oral Solution"))
# f-468   (valueset (vs_name "tricyclic_antidepressants") (code 313496) (label "Trimipramine 100 MG Oral Capsule"))
# f-469   (valueset (vs_name "tricyclic_antidepressants") (code 313497) (label "Trimipramine 100 MG Oral Tablet"))
# f-470   (valueset (vs_name "tricyclic_antidepressants") (code 313498) (label "Trimipramine 25 MG Oral Capsule"))
# f-471   (valueset (vs_name "tricyclic_antidepressants") (code 313499) (label "Trimipramine 50 MG Oral Capsule"))
# f-472   (valueset (vs_name "tricyclic_antidepressants") (code 317136) (label "Nortriptyline 25 MG Oral Capsule"))
# f-473   (valueset (vs_name "tricyclic_antidepressants") (code 835564) (label "Imipramine Hydrochloride 25 MG Oral Tablet"))
# f-474   (valueset (vs_name "tricyclic_antidepressants") (code 835568) (label "Imipramine Hydrochloride 50 MG Oral Tablet"))
# f-475   (valueset (vs_name "tricyclic_antidepressants") (code 835572) (label "Imipramine pamoate 75 MG Oral Capsule"))
# f-476   (valueset (vs_name "tricyclic_antidepressants") (code 835577) (label "Imipramine pamoate 150 MG Oral Capsule"))
# f-477   (valueset (vs_name "tricyclic_antidepressants") (code 835586) (label "Imipramine Hydrochloride 5 MG/ML Oral Solution"))
# f-478   (valueset (vs_name "tricyclic_antidepressants") (code 835589) (label "Imipramine pamoate 125 MG Oral Capsule"))
# f-479   (valueset (vs_name "tricyclic_antidepressants") (code 835591) (label "Imipramine pamoate 100 MG Oral Capsule"))
# f-480   (valueset (vs_name "tricyclic_antidepressants") (code 835593) (label "Imipramine Hydrochloride 10 MG Oral Tablet"))
# f-481   (valueset (vs_name "tricyclic_antidepressants") (code 856706) (label "Amitriptyline Hydrochloride 10 MG / Perphenazine 2 MG Oral Tablet"))
# f-482   (valueset (vs_name "tricyclic_antidepressants") (code 856720) (label "Amitriptyline Hydrochloride 10 MG / Perphenazine 4 MG Oral Tablet"))
# f-483   (valueset (vs_name "tricyclic_antidepressants") (code 856762) (label "Amitriptyline Hydrochloride 100 MG Oral Tablet"))
# f-484   (valueset (vs_name "tricyclic_antidepressants") (code 856769) (label "Amitriptyline Hydrochloride 12.5 MG / Chlordiazepoxide 5 MG Oral Tablet"))
# f-485   (valueset (vs_name "tricyclic_antidepressants") (code 856773) (label "Amitriptyline Hydrochloride 150 MG Oral Tablet"))
# f-486   (valueset (vs_name "tricyclic_antidepressants") (code 856783) (label "Amitriptyline Hydrochloride 10 MG Oral Tablet"))
# f-487   (valueset (vs_name "tricyclic_antidepressants") (code 856792) (label "Amitriptyline Hydrochloride 25 MG / Chlordiazepoxide 10 MG Oral Tablet"))
# f-488   (valueset (vs_name "tricyclic_antidepressants") (code 856797) (label "Amitriptyline Hydrochloride 25 MG / Perphenazine 2 MG Oral Tablet"))
# f-489   (valueset (vs_name "tricyclic_antidepressants") (code 856825) (label "Amitriptyline Hydrochloride 25 MG / Perphenazine 4 MG Oral Tablet"))
# f-490   (valueset (vs_name "tricyclic_antidepressants") (code 856834) (label "Amitriptyline Hydrochloride 25 MG Oral Tablet"))
# f-491   (valueset (vs_name "tricyclic_antidepressants") (code 856840) (label "Amitriptyline Hydrochloride 50 MG / Perphenazine 4 MG Oral Tablet"))
# f-492   (valueset (vs_name "tricyclic_antidepressants") (code 856845) (label "Amitriptyline Hydrochloride 50 MG Oral Tablet"))
# f-493   (valueset (vs_name "tricyclic_antidepressants") (code 856853) (label "Amitriptyline Hydrochloride 75 MG Oral Tablet"))
# f-494   (valueset (vs_name "tricyclic_antidepressants") (code 856862) (label "Amitriptyline Hydrochloride 10 MG/ML Oral Solution"))
# f-495   (valueset (vs_name "tricyclic_antidepressants") (code 856863) (label "Amitriptyline Hydrochloride 12.5 MG / Chlordiazepoxide 10 MG Oral Tablet"))
# f-496   (valueset (vs_name "tricyclic_antidepressants") (code 856865) (label "Amitriptyline Hydrochloride 25 MG Extended Release Oral Capsule"))
# f-497   (valueset (vs_name "tricyclic_antidepressants") (code 856867) (label "Amitriptyline Hydrochloride 5 MG/ML Oral Solution"))
# f-498   (valueset (vs_name "tricyclic_antidepressants") (code 856868) (label "Amitriptyline Hydrochloride 50 MG Extended Release Oral Capsule"))
# f-499   (valueset (vs_name "tricyclic_antidepressants") (code 857289) (label "Clomipramine Hydrochloride 12.5 MG/ML Injectable Solution"))
# f-500   (valueset (vs_name "tricyclic_antidepressants") (code 857291) (label "Clomipramine Hydrochloride 10 MG Oral Tablet"))
# f-501   (valueset (vs_name "tricyclic_antidepressants") (code 857292) (label "Clomipramine Hydrochloride 10 MG Oral Capsule"))
# f-502   (valueset (vs_name "tricyclic_antidepressants") (code 857296) (label "Clomipramine Hydrochloride 25 MG Oral Tablet"))
# f-503   (valueset (vs_name "tricyclic_antidepressants") (code 857297) (label "Clomipramine Hydrochloride 25 MG Oral Capsule"))
# f-504   (valueset (vs_name "tricyclic_antidepressants") (code 857301) (label "Clomipramine Hydrochloride 50 MG Oral Capsule"))
# f-505   (valueset (vs_name "tricyclic_antidepressants") (code 857305) (label "Clomipramine Hydrochloride 75 MG Oral Capsule"))
# f-506   (valueset (vs_name "tricyclic_antidepressants") (code 857315) (label "Clomipramine Hydrochloride 50 MG Oral Tablet"))
# f-507   (valueset (vs_name "tricyclic_antidepressants") (code 857326) (label "Clomipramine Hydrochloride 75 MG Extended Release Oral Tablet"))
# f-508   (valueset (vs_name "tricyclic_antidepressants") (code 865143) (label "Fluphenazine Hydrochloride 0.5 MG / Nortriptyline 10 MG Oral Tablet"))
# f-509   (valueset (vs_name "tricyclic_antidepressants") (code 865146) (label "Fluphenazine Hydrochloride 1.5 MG / Nortriptyline 30 MG Oral Tablet"))
# f-510   (valueset (vs_name "tricyclic_antidepressants") (code 892742) (label "Clomipramine Hydrochloride 20 MG Oral Tablet"))
# f-511   (valueset (vs_name "tricyclic_antidepressants") (code 894759) (label "Clomipramine Hydrochloride 5 MG Oral Tablet"))
# f-512   (valueset (vs_name "tricyclic_antidepressants") (code 894763) (label "Clomipramine Hydrochloride 80 MG Oral Tablet"))
# f-513   (valueset (vs_name "tricyclic_antidepressants") (code 905168) (label "Protriptyline Hydrochloride 10 MG Oral Tablet"))
# f-514   (valueset (vs_name "tricyclic_antidepressants") (code 905172) (label "Protriptyline Hydrochloride 5 MG Oral Tablet"))
# f-515   (valueset (vs_name "tricyclic_antidepressants") (code 966787) (label "Doxepin 3 MG Oral Tablet"))
# f-516   (valueset (vs_name "tricyclic_antidepressants") (code 966793) (label "Doxepin 6 MG Oral Tablet"))
# f-517   (valueset (vs_name "warfarin") (code 855288) (label "Warfarin Sodium 1 MG Oral Tablet"))
# f-518   (valueset (vs_name "warfarin") (code 855296) (label "Warfarin Sodium 10 MG Oral Tablet"))
# f-519   (valueset (vs_name "warfarin") (code 855302) (label "Warfarin Sodium 2 MG Oral Tablet"))
# f-520   (valueset (vs_name "warfarin") (code 855312) (label "Warfarin Sodium 2.5 MG Oral Tablet"))
# f-521   (valueset (vs_name "warfarin") (code 855318) (label "Warfarin Sodium 3 MG Oral Tablet"))
# f-522   (valueset (vs_name "warfarin") (code 855324) (label "Warfarin Sodium 4 MG Oral Tablet"))
# f-523   (valueset (vs_name "warfarin") (code 855332) (label "Warfarin Sodium 5 MG Oral Tablet"))
# f-524   (valueset (vs_name "warfarin") (code 855338) (label "Warfarin Sodium 6 MG Oral Tablet"))
# f-525   (valueset (vs_name "warfarin") (code 855344) (label "Warfarin Sodium 7.5 MG Oral Tablet"))

# %% [markdown]
# #### Obtain all Patient, MedicationStatement, and Condition resources in FHIR STU3
#
# NOTE: You can browse the FHIR data directly at http://130.49.206.139:8080/omoponfhir-stu3/fhir (NOTE: You HAVE to be logged into the Pitt VPN with the correct DBMI role)

# %%
# Using https://github.com/dbmi-pitt/client-py.git for FHIR STU3 
# and our own synthetic data on AWS
from fhirclient import client
settings = {
    'app_id':'no matter',
    'api_base': 'http://130.49.206.139:8080/omoponfhir-stu3/fhir/'
}
syn_omop = client.FHIRClient(settings=settings)

# This global variable is where we write statements we want to see printed. We can print the value of the 
# variable out when we want to view it
env.build('(defglobal ?*log* = (format nil "INFO:%n"))')

# %%
import fhirclient.models.patient as patient_state
search = patient_state.Patient.where(struct={})
patient_states = search.perform_resources(syn_omop.server)
print("{} Patient states".format(len(patient_states)))
print("Example:\n\t{}".format(patient_states[0].as_json()))
# Out:
# 79 Patient states
# Example:
# 	{'id': '1495', 'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']}, 'extension': [{'extension': [{'url': 'ombCategory', 'valueCoding': {'code': '2106-3', 'display': 'White', 'system': 'urn:oid:2.16.840.1.113883.6.238'}}], 'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race'}, {'extension': [{'url': 'ombCategory', 'valueCoding': {'code': '2186-5', 'display': 'Non Hispanic or Latino', 'system': 'urn:oid:2.16.840.1.113883.6.238'}}], 'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity'}], 'text': {'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText"></div><table class="hapiPropertyTable"><tbody><tr><td>Address</td><td><span>null </span><br/><span>null </span><br/></td></tr><tr><td>Date of birth</td><td><span>01 January 1935</span></td></tr></tbody></table></div>', 'status': 'generated'}, 'active': False, 'address': [{'use': 'home'}], 'birthDate': '1935-01-01', 'gender': 'male', 'resourceType': 'Patient'}

# %%
import fhirclient.models.medicationstatement as mstate
search = mstate.MedicationStatement.where(struct={})
medstates = search.perform_resources(syn_omop.server)
print("{} MedicationPlan states".format(len(medstates)))
print("Example:\n\t{}".format(medstates[0].as_json()))
# Out:
# 100 MedicationPlan states
# Example:
# 	{'id': '160000', 'dosage': [{'text': '3 times daily'}], 'effectivePeriod': {'end': '2008-04-27T00:00:00+00:00', 'start': '2008-02-13T00:00:00+00:00'}, 'medicationCodeableConcept': {'coding': [{'code': '855296', 'display': 'Warfarin Sodium 10 MG Oral Tablet', 'system': 'http://www.nlm.nih.gov/research/umls/rxnorm'}]}, 'subject': {'reference': 'Patient/1495'}, 'resourceType': 'MedicationStatement'}

# %%
import fhirclient.models.condition as condstate
search = condstate.Condition.where(struct={})
condstates = search.perform_resources(syn_omop.server)
print("{} Condition states".format(len(condstates)))
print("Example:\n\t{}".format(condstates[0].as_json()))
# Out:
# 8 Condition states
# Example:
# 	{'id': '140000', 'abatementDateTime': '2008-04-27T00:00:00+00:00', 'category': [{'coding': [{'code': 'OMOP generated', 'display': 'EHR encounter diagnosis', 'system': 'None'}]}], 'code': {'coding': [{'code': '12274003', 'display': 'Acute peptic ulcer with hemorrhage', 'system': 'http://snomed.info/sct'}]}, 'onsetDateTime': '2008-02-13T00:00:00+00:00', 'subject': {'reference': 'Patient/1496'}, 'resourceType': 'Condition'}
